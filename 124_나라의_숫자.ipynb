# %%
def solution(n):
    str_ = ''
    num = n 
    while True:
        if num % 3 == 1:
            str_ += '1'
        elif num % 3 == 2:
            str_ += '2'
        else:
            num = num-1
            str_ += '4'
            if num == 3:
                break
        num = num//3
        if num == 0:
            break
    return str_[::-1]
