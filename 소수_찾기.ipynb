# %%
def solution(n):
    if n < 2 or n > 1000000:
        return False
    else:
        if n == 2:
            answer = [2]
            return len(answer)
        elif n == 3 or n == 4:
            answer = [2,3]
            return len(answer)
        else:
            answer = [2,3]
            for i in range(5,n+1,2):
                is_Prime = 1
                for k in range(2,(int((i)**0.5)+1)):
                    if i%k == 0:
                        is_Prime = 0
                        break
                if is_Prime == 1:
                    answer.append(i)
            return len(answer)
