# %%
def solution(s):
    answer = []
    s = s.replace('{',"")
    s = s.replace("}","")
    s = s.split(',')
    k = set(s)
    for i in k:
        answer.append(s.count(i))
    print(answer)
    s = list(k)
    stack = []
    for i in s:
        stack.append(int(i))
    tt = []
    while sum(answer) >0:
        tt.append(stack[answer.index(max(answer))])
        answer[answer.index(max(answer))] = 0
    return tt
