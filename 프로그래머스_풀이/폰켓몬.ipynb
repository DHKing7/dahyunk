# %%
def solution(nums):
    stack = []
    for i in nums:
        if len(stack) == 0:
            stack.append(i)
        else:
            if i not in stack:
                stack.append(i)
    if len(nums)/2 <= len(stack):
        return len(nums)/2
    else:
        return len(stack)
