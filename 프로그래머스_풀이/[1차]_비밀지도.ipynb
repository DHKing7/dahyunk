# %%
def solution(n, arr1, arr2):
    answer = []
    new_arr = []
    for a,b in zip(arr1,arr2):
        t = bin(a)[2:]
        while len(t) < n:
            t = '0' + t
        k = bin(b)[2:]    
        while len(k) < n:
            k = '0' + k
        new = t+k
        answer.append(t+k)
    for i in answer:
        p = ''
        for k in range(n):
            if i[k] == i[k+n]:
                if i[k] == '1':
                    p+='#'
                else:
                    p+=' '
            else:
                p +='#'
        new_arr.append(p)
    return new_arr
