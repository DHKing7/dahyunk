# %%
def solution(s):
    answer= []
    stack = s.split(' ')
    b = ''
    for i in stack:
        a = list(i)
        for k in range(0,len(i),2):
            a[k] = a[k].upper()
        for k in range(1,len(i),2):
            a[k] = a[k].lower()
        b = ''.join(s for s in a)
        answer.append(b)
    return ' '.join(s for s in answer)
