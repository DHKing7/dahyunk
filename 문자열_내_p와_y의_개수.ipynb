# %%
def solution(s):
    dic = { 'p' : 0,
          'y' : 0}
    for i in s.lower():
        if i in dic:
            dic[i] += 1
    if dic['p'] == dic['y']:
        return True
    else:
        return False
